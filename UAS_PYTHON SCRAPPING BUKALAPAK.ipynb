# %%
from bs4 import BeautifulSoup as bs
import requests as req
import glob, json, os, csv, time

# Base URL and API URL for Bukalapak
baseurl = 'https://www.bukalapak.com/u/'
apiurl = 'https://api.bukalapak.com/stores/'

class Bukalapak:
    def __init__(self, username):
        self.username = username
        self.urltoko = baseurl + username
        self.headerbrowser = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:74.0) Gecko/20100101 Firefox/74.0'}
        
        # Send a GET request to the seller's page
        pg_data = req.get(self.urltoko, headers=self.headerbrowser, timeout=3000)
        try:
            if pg_data.status_code == 200:
                soup = bs(pg_data.text, 'html.parser')
                
                # Get the seller's ID
                print("[+] Mengambil id penjual ...")
                self.idseller = soup.find('a', attrs={'data-user-id': True}).get('data-user-id')
                print("[+] Id penjual: " + self.idseller)
                
                # Get the access token for the API
                print("[+] Mengambil access token ...")
                stoken = soup.find_all('script')
                gtoken = str(stoken[4]).replace("<script>localStorage.setItem('bl_token', '", "").replace(
                    "');</script>", "")
                gtoken = json.loads(str(gtoken))
                self.token = gtoken['access_token']
                print("[+] Access token: " + self.token)
                
                # Start grabbing the products
                self.grabproduk()
            else:
                print("[!] Username tidak ditemukan!")
        except Exception as e:
            print(e)
            print("[!] Website down!")
            exit()

    def grabproduk(self):
        print("=== GRABBING PRODUK ===")
        print("[+] Memulai download halaman produk ...")
        print("\x1B[3m" + "(delay 3 detik untuk menghindari anti-spam!)" + "\x1B[0m")
        
        # Get the total number of products from the API
        api = apiurl + str(self.idseller) + '/products?offset=0&limit=50&access_token=' + self.token
        total_product = req.get(api, headers=self.headerbrowser, timeout=3000).json()
        print("[+] Total produk: " + str(total_product['meta']['total']))
        
        # Remove old files
        print("[+] Hapus file lama ...")
        if not os.path.exists("data"):
            os.makedirs("data")
        for filename in glob.glob("data/" + str(self.idseller) + "_bukalapak*.json"):
            os.remove(filename)
        for filename in glob.glob(str(self.idseller) + "_bukalapak.csv"):
            os.remove(filename)
        
        # Grab each page of products
        a = 0
        b = 0
        while True:
            print("-> download halaman ke-" + str(b + 1))
            api = apiurl + str(self.idseller) + '/products?offset=' + str(a) + '&limit=50&access_token=' + self.token
            pg_data = req.get(api, headers=self.headerbrowser, timeout=3000).json()
            
            # If there are no more products, break the loop
            if len(pg_data['data']) == 0:
                break
            
            # Save the product data to a JSON file
            with open("data/" + str(self.idseller) + "_bukalapak" + str(b) + ".json", 'w') as json_file:
                json.dump(pg_data['data'], json_file)
            
            # Increment offsets and wait for 3 seconds to avoid anti-spam measures
            a += 50
            b += 1
            time.sleep(3)
        
        # Merge all JSON files into one
        print("[+] Merging data produk ...")
        data = []
        for f in glob.glob("data/" + str(self.idseller) + "_bukalapak*.json"):
            with open(f) as infile:
                data.extend(json.load(infile))
        with open("data/" + str(self.idseller) + "_bukalapak_all.json", 'w') as outfile:
            json.dump(data, outfile)
        
        # Create a CSV file with the product data
        print("[+] Membuat csv data produk ...")
        f_data = []
        for i in data:
            f_data.append([
                self.idseller,
                self.username,
                i['store']['name'],
                i['store']['level']['name'],
                i['store']['premium_level'],
                i['id'],
                i['name'],
                i['category']['name'],
                i['condition'],
                i['rating']['average_rate'],
                i['rating']['user_count'],
                i['stock'],
                i['stats']['interest_count'],
                i['stats']['sold_count'],
                i['stats']['view_count'],
                i['price'],
                i['original_price'],
                i['discount_percentage'],
                i['description']
            ])
        
        f_header = [
            'id_seller', 'username', 'nama_toko', 'level_toko', 'premium_toko', 'id_produk', 'nama_produk',
            'kategori', 'kondisi', 'rating', 'jumlah_rating', 'stok', 'jumlah_interest', 'jumlah_sold',
            'jumlah_view', 'harga', 'harga_asli', 'diskon', 'deskripsi'
        ]
        
        with open(str(self.idseller) + '_bukalapak.csv', 'w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            writer.writerow(f_header)
            writer.writerows(f_data)
        
        print('done! ' + str(self.idseller) + '_bukalapak.csv')


print("[+] https://github.com/heryandp/bukalapak-product-scrap")
sname = input("[+] Masukkan username seller: https://www.bukalapak.com/u/")
act = Bukalapak(sname)
# Out:
# [+] https://github.com/heryandp/bukalapak-product-scrap
# [+] Masukkan username seller: https://www.bukalapak.com/u/whitestonelapak
# [+] Mengambil id penjual ...
# [+] Id penjual: 379098398
# [+] Mengambil access token ...
# [+] Access token: eyJhbGciOiJSUzI1NiIsImtpZCI6ImFjY291bnRzLmp3dC5hY2Nlc3MtdG9rZW4iLCJ0eXAiOiJKV1QifQ.....YQZGaWje8jSTmU3uAT72I_nOpUk94BdnOFrLYPdVTJ81zfWKmHjlzWpp90z3tfm6J3-vLQm74QI6tN1V5naMFPrEukwVxo04p4a0gny8P1jiiNpsK6fQUAYKQ5JxsK0kbP4b30CHOd_KEVnhUS8tVDL9koSuXUTaBbf74H2WwMjKVpe8jcTg5l7Pbs0j7a_M5X01c25nqRGZuIGelO-6Q4gf60HFr2DDq6eoiMnQV2A6XRvJcbZXRW-LiJoSkJjnaVCoGmd7hM9oI_wQlXWt3TP8KMs2e0sVNYTiYpCZJGrnTCU0MRmJpJpq1aN5I3ggT4fmgDAboadr7FqTF2-I4Q
# === GRABBING PRODUK ===
# [+] Memulai download halaman produk ...
# (delay 3 detik untuk menghindari anti-spam!)
# [+] Total produk: 52
# [+] Hapus file lama ...
# -> download halaman ke-1
# -> download halaman ke-2
# -> download halaman ke-3
# [+] Merging data produk ...
# [+] Membuat csv data produk ...
# done! 379098398_bukalapak.csv

# %%
import pandas as pd

# reading the database
data = pd.read_csv("379098398_bukalapak.csv")

# printing the top 52 rows
display(data.head(52))
# Out:
#     id_seller         username    nama_toko level_toko premium_toko id_produk  \
# 0   379098398  whitestonelapak  White Stone    Juragan     platinum   4hk99v4
# 1   379098398  whitestonelapak  White Stone    Juragan     platinum   4hjl8t7
# 2   379098398  whitestonelapak  White Stone    Juragan     platinum   4hj9uov
# 3   379098398  whitestonelapak  White Stone    Juragan     platinum   4hiszxp
# 4   379098398  whitestonelapak  White Stone    Juragan     platinum   4hisztv
# 5   379098398  whitestonelapak  White Stone    Juragan     platinum   4hiszny
# 6   379098398  whitestonelapak  White Stone    Juragan     platinum   4hipku1
# 7   379098398  whitestonelapak  White Stone    Juragan     platinum   4gtquts
# 8   379098398  whitestonelapak  White Stone    Juragan     platinum   4bueinj
# 9   379098398  whitestonelapak  White Stone    Juragan     platinum   48sbuau
# 46    Baru     4.7             43     1               36          158
# 47    Baru     5.0            495  1757               63         2357
# 48    Baru     5.0            643  2045              268         8673
# 49    Baru     5.0            640  2048              251         8683
# 50    Baru     5.0             46     1               41          151
# 51    Baru     4.9            109    99               87          399
#
#     jumlah_view   harga  harga_asli  diskon  \
# 0             0   23000       23000       0
# 1             0  179000      200000      11
# 2             0  179000      200000      11
# 3             0   25000       25000       0
# 4             0   15000       15000       0
# 5             0   10000       10000       0
# 6             0    6000        6000       0
# 7             0  179000      200000      11
# 8             0  178000      178000       0
# 9             0  223000      223000       0
# 10            0  135000      135000       0
# 11            0  140500      140500       0
# 12            0  150000      150000       0
# 13            0  159000      228000      30
# 14            0  159000      229000      31
# 15            0  149000      199000      25
# 16            0  199000      199000       0
# 17            0  355000      355000       0
# 18            0  175000      175000       0
# 19            0  169000      220000      23
# 20            0  190000      190000       0
# 21            0  220000      220000       0
# 22            0  159000      199500      20
# 23            0  285000      285000       0
# 24            0  235000      235000       0
# 25            0  195000      195000       0
# 26            0  189000      189000       0
# 27            0  135000      192000      30
# 28            0  270000      270000       0
# 29            0  160000      160000       0
# 30            0  160000      160000       0
# 31            0  155000      155000       0
# 32            0  189000      189000       0
# 33            0  189000      189000       0
# 34            0  199000      199000       0
# 35            0  189000      189000       0
# 36            0  153500      153500       0
# 37            0  167500      167500       0
# 38            0  163500      163500       0
# 39            0  163500      163500       0
# 40            0  163500      163500       0
# 41            0  195000      195000       0
# 42            0  266000      266000       0
# 43            0  169000      298000      43
# 44            0  200000      200000       0
# 45            0  200000      200000       0
# 46            0  200000      200000       0
# 47            0  200000      200000       0
# 48            0  200000      200000       0
# 49            0  230000      230000       0
# 50            0  220000      220000       0
# 51            0  230000      230000       0
#
#                                             deskripsi
# 0   MODEL PAKAI WARNA MOCCA YA <br><br/><br><br/> ...
# 1   JEANS SLIM<br><br/><br><br/>MATERIAL : FULL PR...
# 2   Geser photo untuk detail produk<br><br/><br><b...
# 3   ready stok mainan latto latto mainan jadul mai...
# 4   ready stok mainan latto latto mainan jadul mai...
# 5   ready stok mainan latto latto mainan jadul mai...
# 6   ready stok mainan latto latto mainan jadul mai...
# 7   JEANS SLIM<br><br/><br><br/>MATERIAL :FULL PRE...
# 8   Geser photo untuk detail produk<br><br/><br><b...
# 9   JEANS SLIM<br><br/><br><br/>MATERIAL : FULL PR...
# 10  Payung LIPAT TRANSPARAN TABASA Bening Korea Je...
# 11  Ingin punya payung ukuran besar yang biasa bel...
# 12  Warna ready: , Ungu, Hijau Muda, Orange, Merah...
# 13  Sepatu Pria Original 100%<br><br/>Sepatu Impor...
# 14  BONUS : FREE BOX &amp; KAOS KAKI<br><br/><br><...
# 15  Kepada calon pembeli dimohon untuk membaca des...
# 16  Kepada calon pembeli dimohon untuk membaca des...
# 17  Helm Sepeda Avand A 28 Safety Helmet Bicycle E...
# 18  =&gt;Nama Model : Almira Dress<br><br/>=&gt;Wa...
# 19  bahan katun micro yang dibuat khusus mukena ad...
# 20  HOT SALE =&gt; BUY 10 GET 1 ( RANDOM )<br><br/...
# 21  Mukena Bali Ichio Sakura<br><br/><br><br/>Supe...
# 22  =&gt;Nama Model : Ziva Dress<br><br/>=&gt;Warn...
# 23  GAMIS NIBRAS NB A38<br/><br/>Berat : 432 gram<...
# 24  WARNA TERSEDIA:<br><br/>- putih<br><br/>- hita...
# 25  MUKENA VALERI ANAK TAS RANSEL<br><br/>.<br><br...
# 26  Warna Tersedia:<br><br/>- broken white<br><br/...
# 27  Matt : Toyobo Tebal<br><br/>High Quality<br><b...
# 28  Warna tersedia:<br><br/>- green kombi grey<br>...
# 29  ( UNISEX )<br/>BAHAN : COTTON TAIWAN ( 100% FU...
# 30  ( UNISEX )<br/>BAHAN : COTTON TAIWAN ( 100% FU...
# 31  Warna:<br/>- Black<br/>- Mocca<br/>- Stone<br/...
# 32  JEANS SLIM<br><br/><br><br/>MATERIAL : FULL PR...
# 33  JEANS SLIM<br><br/><br><br/>MATERIAL : FULL PR...
# 34  JEANS SLIM<br><br/><br><br/>MATERIAL : FULL PR...
# 35  JEANS SLIM<br><br/><br><br/>MATERIAL : FULL PR...
# 36  Estimasi Size (Lebar x Panjang) :<br><br/>M = ...
# 37  Estimasi Size (Lebar x Panjang) :<br/>M = 50x8...
# 38  Estimasi Size (Lebar x Panjang) :<br/>M = 50x7...
# 39  Estimasi Size (Lebar x Panjang) :<br/>M = 50x7...
# 40  Estimasi Size (Lebar x Panjang) :<br/>M = 50x7...
# 41  Batik Modern &amp; Millenials <br><br/><br><br...
# 42  Sepatu sneakers - sepatu running casual - sepa...
# 43  New Arrival!!!<br><br/><br><br/>BONUS : FREE B...
# 44  BAHAN : FLEECE <br><br/><br><br/>Cantumkan war...
# 45  Budayakan membaca deskripsi produk agar tidak ...
# 46  Geser foto untuk detail produk<br><br/><br><br...
# 47  Selamat datang &amp; selamat belanja di toko k...
# 48  Geser foto untuk detail produk<br><br/><br><br...
# 49  Jaket Bomber Unisex<br><br/><br><br/>BAHAN : K...
# 50  Jaket Paska (Unisex)<br><br/><br><br/>BAHAN : ...
# 51  Jaket Bomber (unisex)<br><br/><br><br/>BAHAN :...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Reading the database
data = pd.read_csv("379098398_bukalapak.csv")

# Selecting the first 50 data points
data_subset = data.head(52)

# Scatter plot with 'rating' against 'jumlah_rating'
plt.scatter(data_subset['rating'], data_subset['jumlah_rating'])

# Adding title to the plot
plt.title("Bukalapak - Scatter Plot")

# Setting the x and y labels
plt.xlabel('rating')
plt.ylabel('jumlah_rating')

# Save the plot as a PNG file
plt.savefig('scatter_plot.png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# reading the database
data = pd.read_csv("379098398_bukalapak.csv")

# Mengambil hanya 50 data pertama
data_52 = data.head(52)

# Line plot dengan jumlah_sold dan kategori
plt.plot(data_52['rating'])
plt.plot(data_52['jumlah_rating'])

# Menambahkan judul pada plot
plt.title("")

# Mengatur label sumbu X dan Y
plt.ylabel('jumlah_rating')
plt.xlabel('rating')

# Save the plot as a PNG file
plt.savefig('line_chart.png', dpi=300, bbox_inches='tight')

plt.show()
